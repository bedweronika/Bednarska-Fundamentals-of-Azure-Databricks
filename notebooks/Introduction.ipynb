# %% [markdown]
# &copy; 2026 Weronika Bednarska. All rights reserved

# %%
msg = "Hello World"

# %%
print(msg)
# Out:
# Hello World

# %%
# %sql
Select "Hello World"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Hello World</th></tr></thead><tbody><tr><td>Hello World</td></tr></tbody></table></div>

# %%
# %scala
var msg = "Hello World"
print(msg)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Hello Worldvar msg: String = Hello World
# </div>

# %%
# %fs
ls /databricks-datasets
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/COVID/</td><td>COVID/</td><td>0</td><td>1769787516999</td></tr><tr><td>dbfs:/databricks-datasets/README.md</td><td>README.md</td><td>976</td><td>1532502324000</td></tr><tr><td>dbfs:/databricks-datasets/Rdatasets/</td><td>Rdatasets/</td><td>0</td><td>1769787516999</td></tr><tr><td>dbfs:/databricks-datasets/SPARK_README.md</td><td>SPARK_README.md</td><td>3359</td><td>1511905961000</td></tr><tr><td>dbfs:/databricks-datasets/adult/</td><td>adult/</td><td>0</td><td>1769787516999</td></tr><tr><td>dbfs:/databricks-datasets/airlines/</td><td>airlines/</td><td>0</td><td>1769787516999</td></tr><tr><td>dbfs:/databricks-datasets/amazon/</td><td>amazon/</td><td>0</td><td>1769787516999</td></tr><tr><td>dbfs:/databricks-datasets/asa/</td><td>asa/</td><td>0</td><td>1769787516999</td></tr><tr><td>dbfs:/databricks-datasets/atlas_higgs/</td><td>atlas_higgs/</td><td>0</td><td>1769787516999</td></tr><tr><td>dbfs:/databricks-datasets/bikeSharing/</td><td>bikeSharing/</td><td>0</td><td>1769787516999</td></tr><tr><td>dbfs:/databricks-datasets/cctvVideos/</td><td>cctvVideos/</td><td>0</td><td>1769787516999</td></tr><tr><td>dbfs:/databricks-datasets/credit-card-fraud/</td><td>credit-card-fraud/</td><td>0</td><td>1769787516999</td></tr><tr><td>dbfs:/databricks-datasets/cs100/</td><td>cs100/</td><td>0</td><td>1769787516999</td></tr><tr><td>dbfs:/databricks-datasets/cs110x/</td><td>cs110x/</td><td>0</td><td>1769787516999</td></tr><tr><td>dbfs:/databricks-datasets/cs190/</td><td>cs190/</td><td>0</td><td>1769787516999</td></tr><tr><td>dbfs:/databricks-datasets/data.gov/</td><td>data.gov/</td><td>0</td><td>1769787516999</td></tr><tr><td>dbfs:/databricks-datasets/definitive-guide/</td><td>definitive-guide/</td><td>0</td><td>1769787516999</td></tr><tr><td>dbfs:/databricks-datasets/delta-sharing/</td><td>delta-sharing/</td><td>0</td><td>1769787516999</td></tr><tr><td>dbfs:/databricks-datasets/flights/</td><td>flights/</td><td>0</td><td>1769787516999</td></tr><tr><td>dbfs:/databricks-datasets/flower_photos/</td><td>flower_photos/</td><td>0</td><td>1769787516999</td></tr><tr><td>dbfs:/databricks-datasets/flowers/</td><td>flowers/</td><td>0</td><td>1769787516999</td></tr><tr><td>dbfs:/databricks-datasets/genomics/</td><td>genomics/</td><td>0</td><td>1769787516999</td></tr><tr><td>dbfs:/databricks-datasets/hail/</td><td>hail/</td><td>0</td><td>1769787516999</td></tr><tr><td>dbfs:/databricks-datasets/identifying-campaign-effectiveness/</td><td>identifying-campaign-effectiveness/</td><
td></tr><tr><td>dbfs:/databricks-datasets/airlines/part-00023</td><td>part-00023</td><td>67108926</td><td>1511906174000</td></tr><tr><td>dbfs:/databricks-datasets/airlines/part-00024</td><td>part-00024</td><td>67108885</td><td>1511906181000</td></tr><tr><td>dbfs:/databricks-datasets/airlines/part-00025</td><td>part-00025</td><td>67108843</td><td>1511906193000</td></tr><tr><td>dbfs:/databricks-datasets/airlines/part-00026</td><td>part-00026</td><td>67108837</td><td>1511906200000</td></tr><tr><td>dbfs:/databricks-datasets/airlines/part-00027</td><td>part-00027</td><td>67108911</td><td>1511906210000</td></tr><tr><td>dbfs:/databricks-datasets/airlines/part-00028</td><td>part-00028</td><td>67108776</td><td>1511906218000</td></tr><tr><td>dbfs:/databricks-datasets/airlines/part-00029</td><td>part- ...

# %%
# %sh
tail /databricks-datasets/airlines/part-00000
# Out:
# 1987,11,19,4,1231,1224,1413,1423,PI,542,NA,102,119,NA,-10,7,CLT,BOS,728,NA,NA,0,NA,0,NA,NA,NA,NA,NA,NO,YES
# 1987,11,20,5,1224,1224,1414,1423,PI,542,NA,110,119,NA,-9,0,CLT,BOS,728,NA,NA,0,NA,0,NA,NA,NA,NA,NA,NO,NO
# 1987,11,21,6,1231,1224,1423,1423,PI,542,NA,112,119,NA,0,7,CLT,BOS,728,NA,NA,0,NA,0,NA,NA,NA,NA,NA,NO,YES
# 1987,11,22,7,1225,1224,1422,1423,PI,542,NA,117,119,NA,-1,1,CLT,BOS,728,NA,NA,0,NA,0,NA,NA,NA,NA,NA,NO,YES
# 1987,11,23,1,1230,1224,1435,1423,PI,542,NA,125,119,NA,12,6,CLT,BOS,728,NA,NA,0,NA,0,NA,NA,NA,NA,NA,YES,YES
# 1987,11,24,2,1238,1224,1433,1423,PI,542,NA,115,119,NA,10,14,CLT,BOS,728,NA,NA,0,NA,0,NA,NA,NA,NA,NA,YES,YES
# 1987,11,25,3,1232,1224,1425,1423,PI,542,NA,113,119,NA,2,8,CLT,BOS,728,NA,NA,0,NA,0,NA,NA,NA,NA,NA,YES,YES
# 1987,11,26,4,1225,1224,1411,1423,PI,542,NA,106,119,NA,-12,1,CLT,BOS,728,NA,NA,0,NA,0,NA,NA,NA,NA,NA,NO,YES
# 1987,11,27,5,1227,1224,1426,1423,PI,542,NA,119,119,NA,3,3,CLT,BOS,728,NA,NA,0,NA,0,NA,NA,NA,NA,NA,YES,YES
# 1987,11,28,6,1237,1224,1441,1423,PI,542,NA,124,119,NA,18,13,CLT,BOS,728,NA,NA,0,NA,0,NA,NA,NA,NA,NA,YES,YES

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %code_wrap  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %mamba  %man  %matplotlib  %micromamba  %mkdir  %more  %mv  %notebook  %oprofile  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %pipeline_codegen  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %restart_python  %rm  %rmdir  %run  %save  %sc  %set_cell_max_output_size_in_mb  %set_env  %store  %sx  %system  %tb  %time  %timeit  %top  %unalias  %unload_ext  %uv  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%code_wrap  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%memprofile  %%oprofile  %%perl  %%pipeline_codegen  %%profile  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%sql  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %%
# %pip??
# Out:
# Source:
#     @line_magic
#     def pip(self, line):
#         line = self.quote_package_specifiers(line)
#         if self.pipMagicHandler is None:
#             self.orig_pip_magic(line)
#         else:
#             self.pipMagicHandler.runCmd("pip", line)
# File:   /databricks/python_shell/lib/dbruntime/PipMagicOverrides.py
# Line:   80
